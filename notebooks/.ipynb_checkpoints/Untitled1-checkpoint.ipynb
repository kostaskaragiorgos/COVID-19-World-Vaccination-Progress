# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../vaccinations.csv')
df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
dfcovid = pd.read_csv("../covid_19_clean_complete.csv")
dfcovid
# Out:
#                  Province/State  Country/Region      Lat     Long     Date  \
# 0                           NaN     Afghanistan  33.0000  65.0000  1/22/20
# 1                           NaN         Albania  41.1533  20.1683  1/22/20
# 2                           NaN         Algeria  28.0339   1.6596  1/22/20
# 3                           NaN         Andorra  42.5063   1.5218  1/22/20
# 4                           NaN          Angola -11.2027  17.8739  1/22/20
# ...                         ...             ...      ...      ...      ...
# 17131                       NaN           Burma  21.9162  95.9560  3/29/20
# 17132                  Anguilla  United Kingdom  18.2206 -63.0686  3/29/20
# 17133    British Virgin Islands  United Kingdom  18.4207 -64.6400  3/29/20
# 17134  Turks and Caicos Islands  United Kingdom  21.6940 -71.7979  3/29/20
# 17135                       NaN      MS Zaandam   0.0000   0.0000  3/29/20
#
#        Confirmed  Deaths  Recovered
# ...

# %%
df.drop_duplicates(subset='location', keep='last', inplace=True)
df["Lat"] = dfcovid["Lat"]
df["Long"] = dfcovid["Long"]

# %%
df.head()
# Out:
#         location iso_code        date  total_vaccinations  people_vaccinated  \
# 93   Afghanistan      AFG  2021-05-26            590454.0           479372.0
# 371      Albania      ALB  2021-05-27            759043.0           481788.0
# 393      Algeria      DZA  2021-02-19             75000.0                NaN
# 506      Andorra      AND  2021-05-17             32317.0            27613.0
# 593       Angola      AGO  2021-05-26            859979.0           663049.0
#
#      people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 93                  111082.0                     NaN              6768.0
# 371                 277255.0                 10057.0              7900.0
# 393                      NaN                     NaN              3748.0
# 506                   4704.0                     NaN                98.0
# 593                 196930.0                     NaN             21876.0
#
# ...

# %%
indexlist = df.location.unique().tolist()
for i in indexlist:
    df[df['location']==str(i)].plot(figsize =(15,10),x='date',y=['total_vaccinations','people_vaccinated', 'people_fully_vaccinated' ], title="Vaccinations of "+str(i))

# %%
df.drop_duplicates(subset='location', keep='last', inplace=True)

# %%
df.head()

# %%
df.loc[(df['location']=="Greece")]

# %%
df['location'] == "Africa"

# %%
df.loc[(df['location']=="Europe")]

# %%
df['total_vaccinations'].max()

# %%
indexlist = ["Asia", "Europe", "Africa", "Middle East", "World", "Upper middle income", "High income","North America", "Lower middle income"]
for i in indexlist:
    print(df.loc[df['location'] == str(i)])

# %%
df.drop(df[df['location']=="Asia"].index, inplace=True)
df.drop(df[df['location']=="Europe"].index, inplace=True)
df.drop(df[df['location']=="Africa"].index, inplace=True)
df.drop(df[df['location']=="Middle East"].index, inplace=True)
df.drop(df[df['location']=="World"].index, inplace=True)
df.drop(df[df['location']=="Upper middle income"].index, inplace=True)
df.drop(df[df['location']=="High income"].index, inplace=True)
df.drop(df[df['location']=="North America"].index, inplace=True)
df.drop(df[df['location']=="Lower middle income"].index, inplace=True)

# %%
df.loc[df['location'] == "World"]

# %%
df[df.total_vaccinations == df['total_vaccinations'].min()]

# %%
df[df.people_fully_vaccinated == df['people_fully_vaccinated'].max()]

# %%
locations = []
index = ["total_vaccinations",	"people_vaccinated",	"people_fully_vaccinated",	"daily_vaccinations_raw"	,"daily_vaccinations",	"total_vaccinations_per_hundred",	"people_vaccinated_per_hundred",	"people_fully_vaccinated_per_hundred",	"daily_vaccinations_per_million"]
for i in index:
    locations.append(str(df[df[str(i)] == df[str(i)].min()][str(i)]))
locations

# %%
locations[0].split()
locations

# %%
df.plot.scatter(x='Lat', y='Long',c='total_vaccinations',colormap="hsv")
